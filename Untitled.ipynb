# %% [markdown]
# 1.
#
# T-критерий применяется для определения того, насколько средние значения двух наборов данных отличаются друг от друга, если дисперсия не задана.
# Z-тест подразумевает проверку гипотезы, которая устанавливает, отличаются ли средние значения двух наборов данных друг от друга, когда дается дисперсия.

# %% [markdown]
# 2.
#
# Утверждается, что шарики для подшипников, изготовленные
# автоматическим станком, имеют средний диаметр 17 мм.
# Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из
# n=100 шариков средний диаметр
# оказался равным 17.5 мм, а дисперсия известна и равна 4 кв. мм.
#
# H0: M = 17 Нулевая гипотеза
# H1: M > 17
#
# n = 100
# Ꭴ = 4
# Ꭴср = √Ꭴ = 2
#
# α = 0,05
# Zt = 1.645 ( т.к. α=0,05)
# Zрасч = 17,5-17,0/√100 = 2,5

# %% [markdown]
# 3.
#
# ![photo1676538964.jpeg](attachment:3e239dc3-2b15-4f59-9be1-62494edd1e3d.jpeg)

# %%
4.

Есть ли статистически значимые различия в росте дочерей и матерей?

Рост матерей 172, 177, 158, 170, 178,175, 164, 160, 169
Рост взрослых дочерей: 173, 175, 162, 174, 175, 168, 155, 170, 160
Будем считать через p_value

p_val > a - принимаем нулевую гипотезу

p_val < a - отвергаем нулевую, принмаем первую

hight_ma = np.array([172, 177, 158, 170, 178,175, 164, 160, 169.])
np.mean(hight_ma)
169.22222222222223
hight_ma_std = hight_ma.std(ddof=1)
hight_ma_std
7.22457226723108
len(hight_ma)
9
hight_do = np.array([173, 175, 162, 174, 175, 168, 155, 170, 160.])
np.mean(hight_do)
168.0
hight_do_std = hight_do.std(ddof=1)
hight_do_std
7.3484692283495345
import scipy.stats as stats
stats.ttest_rel(hight_ma,hight_do)
Ttest_relResult(statistic=0.559522990335608, pvalue=0.5911212354055175)
pvalue = 0,559 > α(альфа) = 0,05
statistic = 0,591 < табличное значение = 2,306

Вывод: верна нулевая теория
